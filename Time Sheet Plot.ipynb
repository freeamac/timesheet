# %%
# %load_ext autoreload
# %autoreload timesheet_parser

# %%
# %matplotlib inline
import timesheet_parser
timesheet_parser.show_percentage_pie_plot()

# %%
import timesheet_parser
timesheet_parser.get_activity_statistics()
# Out:
# Weekday Stats:
# ...
#
# Activity | cnt |  avg |  medium
#          |     | mins |    mins
# ---------+-----+------+--------
# Coding   | 315 |  115 |      93
# ---------+-----+------+--------
# Learning |  39 |   70 |      37
# ---------+-----+------+--------
# Meetings | 187 |   68 |      66
# ---------+-----+------+--------
# Other    | 125 |   77 |      49
# ---------+-----+------+--------
# Slack    |  96 |   24 |      16
# ---------+-----+------+--------
# Reviews  | 168 |   41 |      32
# ---------+-----+------+--------
# Email    | 284 |   36 |      26
# ---------+-----+------+--------
# Support  | 351 |   95 |      61
# ---------+-----+------+--------
# Total days: 242
# Average work day (mins): 474
#
# Weekend Stats:
# ...
#
# Activity | cnt |  avg |  medium
#          |     | mins |    mins
# ---------+-----+------+--------
# Coding   |  19 |   99 |      52
# ---------+-----+------+--------
# Learning |   3 |   42 |      39
# ---------+-----+------+--------
# ...

# %%
timesheet_parser.get_daily_statistics()
# Out:
# Day | Activity | Percenatage
# ----+----------+------------
# mon |Coding    | 42.22 %
#     +----------+------------
#     |Email     |  5.64 %
#     +----------+------------
#     |Learning  |  6.25 %
#     +----------+------------
#     |Meetings  |  0.00 %
#     +----------+------------
#     |Other     |  9.60 %
#     +----------+------------
#     |Reviews   |  2.58 %
#     +----------+------------
#     |Slack     |  1.25 %
#     +----------+------------
#     |Support   | 32.46 %
#     +----------+------------
#     |ctx_sw    |  5.00
#     +----------+------------
#     |work_tm   |384.09 mins
# ----+----------+------------
# tue |Coding    | 26.50 %
#     +----------+------------
#     |Email     |  7.88 %
#     +----------+------------
#     |Learning  |  3.86 %
#     +----------+------------
#     |Meetings  | 13.03 %
#     +----------+------------
#     |Other     | 10.15 %
#     +----------+------------
#     |Reviews   |  7.29 %
#     +----------+------------
# ...

# %%
timesheet_parser.show_wow_activity_plot(activity='Meetings', weeks=4)

# %%
timesheet_parser.print_weekly_timings()
# Out:
# Week: 2016-28
# 	Activity: Coding       Counts:  13	Time:  18 hrs, 58 mins
# 	Activity: Email        Counts:   7	Time:   2 hrs, 50 mins
# 	Activity: Learning     Counts:   2	Time:  12 hrs, 52 mins
# 	Activity: Meetings     Counts:   5	Time:   4 hrs, 14 mins
# 	Activity: Other        Counts:   1	Time:   0 hrs,  0 mins
# 	Activity: Reviews      Counts:   1	Time:   0 hrs,  8 mins
# 	Activity: Slack        Counts:   5	Time:   1 hrs,  7 mins
# 	Activity: Support      Counts:   6	Time:   8 hrs, 28 mins
# Week: 2016-29
# 	Activity: Coding       Counts:   5	Time:   8 hrs,  1 mins
# 	Activity: Email        Counts:   6	Time:   2 hrs, 26 mins
# 	Activity: Learning     Counts:   1	Time:   0 hrs, 41 mins
# 	Activity: Meetings     Counts:   4	Time:   3 hrs, 10 mins
# 	Activity: Other        Counts:   4	Time:   9 hrs, 27 mins
# 	Activity: Reviews      Counts:   1	Time:   0 hrs, 16 mins
# 	Activity: Slack        Counts:   2	Time:   0 hrs, 36 mins
# ...

# %%
from timesheet_parser import plot_day_activity_percentages

# %%
plot_day_activity_percentages()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e0e3fce40b24> in <module>()
# ----> 1 plot_day_activity_percentages()
#
# NameError: name 'plot_day_activity_percentages' is not defined
